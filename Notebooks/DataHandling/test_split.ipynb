# %%
from ml_project_util.load_preprocess import test_split, undo_test_split

# %%
undo_test_split()
# Out:
# *** Training & Validation Classes are:
#
# 0. Bluebell (80 images)
# 1. Buttercup (80 images)
# 2. ColtsFoot (80 images)
# 3. Cowslip (80 images)
# 4. Crocus (80 images)
# 5. Daffodil (80 images)
# 6. Daisy (80 images)
# 7. Dandelion (80 images)
# 8. Fritillary (80 images)
# 9. Iris (80 images)
# 10. LilyValley (80 images)
# 11. Pansy (80 images)
# 12. Snowdrop (80 images)
# 13. Sunflower (80 images)
# 14. Tigerlily (80 images)
# 15. Tulip (80 images)
# 16. Windflower (80 images)
#
# *** Test Classes are:
#
# 0. Bluebell (0 images)
# 1. Buttercup (0 images)
# 2. ColtsFoot (0 images)
# 3. Cowslip (0 images)
# 4. Crocus (0 images)
# 5. Daffodil (0 images)
# 6. Daisy (0 images)
# 7. Dandelion (0 images)
# 8. Fritillary (0 images)
# 9. Iris (0 images)
# 10. LilyValley (0 images)
# 11. Pansy (0 images)
# 12. Snowdrop (0 images)
# 13. Sunflower (0 images)
# 14. Tigerlily (0 images)
# 15. Tulip (0 images)
# 16. Windflower (0 images)
#
# ...

# %%
test_split(percent=25)
# Out:
# *** Training & Validation Classes are:
#
# 0. Bluebell (80 images)
# 1. Buttercup (80 images)
# 2. ColtsFoot (80 images)
# 3. Cowslip (80 images)
# 4. Crocus (80 images)
# 5. Daffodil (80 images)
# 6. Daisy (80 images)
# 7. Dandelion (80 images)
# 8. Fritillary (80 images)
# 9. Iris (80 images)
# 10. LilyValley (80 images)
# 11. Pansy (80 images)
# 12. Snowdrop (80 images)
# 13. Sunflower (80 images)
# 14. Tigerlily (80 images)
# 15. Tulip (80 images)
# 16. Windflower (80 images)
#
# *** Test Classes are:
#
# 0. Bluebell (0 images)
# 1. Buttercup (0 images)
# 2. ColtsFoot (0 images)
# 3. Cowslip (0 images)
# 4. Crocus (0 images)
# 5. Daffodil (0 images)
# 6. Daisy (0 images)
# 7. Dandelion (0 images)
# 8. Fritillary (0 images)
# 9. Iris (0 images)
# 10. LilyValley (0 images)
# 11. Pansy (0 images)
# 12. Snowdrop (0 images)
# 13. Sunflower (0 images)
# 14. Tigerlily (0 images)
# 15. Tulip (0 images)
# 16. Windflower (0 images)
#
# ...

# %% [markdown]
# ---
